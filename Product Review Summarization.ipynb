# %% [markdown]
# ## Problem Statement
# In this project we have to build a system which summarizes the customer reviews of a particular product into a bunch of keywords, so that when a customer goes to a product page, he/she doesn’t have to read long reviews. Instead he/she can make up his/her mind based on the product average rating and summarized keywords of the review.
# For this problem you may use any tools and techniques you like. The data consists of reviews and ratings information of the products which are being sold by the client via online website.
#
# The data description is as follows:
# DATA DESCRIPTION:
# You are given a file named “Cell_Phones_and_Accessories.json”. This file contains review information under following columns:  IC – Item Code of the product, e.g. B016MF3P3K  
#
# Reviewer_Name - Name of the reviewer 
#
# Useful- Number of useful votes (upvotes) of the review  Prod_meta- a dictionary of the product metadata. It contains only additional information about the product, if any available. 
#
# Review- text of the review 
#
# Rating- rating given to the product by the reviewer. 
#
# Rev_summ- summary of the review  Review_timestamp- time when the review has been posted (unix time format) 
#
# Review_Date- Date when the review has been posted  Prod_img- images that users post after they have received the product 
#
# Rev_verify- Flag to represent whether the review has been verified or not. (True/False)
#
# Now, since you have understood the features present in the dataset, you have to do a proper data cleaning for the same. You may remove all the rows where no review is present. You may choose any column(s) to perform this task. You may perform EDA, feature engineering if you are able to find any important new feature.
# Once you have done data pre-processing for all the products, you have to predict the important words which summarize the reviews for each product and thus return those words. Number of words extracted for each topic depends on your understanding, you need to give a suitable reason for the number you choose. The summary keywords should not contain more than 30 words.

# %%
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')
import nltk
import ast
import re
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import WordNetLemmatizer,PorterStemmer
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import wordnet
nltk.download('sentiwordnet')
from nltk.corpus import sentiwordnet
import json
# Out:
# [nltk_data] Downloading package sentiwordnet to C:\Users\Silent
# [nltk_data]     night\AppData\Roaming\nltk_data...
# [nltk_data]   Package sentiwordnet is already up-to-date!

# %%
df=pd.read_json('Cell_Phones_and_Accessories.json')

# %%
df
# Out:
#         Rating  Rev_verify  Review_Date          IC  \
# 0            5        True   09 1, 2015  B009XD5TPQ
# 1            5        True   01 9, 2016  B016MF3P3K
# 2            5        True  04 21, 2013  B008DC8N5G
# 3            3        True  02 27, 2013  B0089CH3TM
# 4            4        True  12 19, 2013  B00AKZWGAC
# ...        ...         ...          ...         ...
# 760445       4       False  07 12, 2014  B00C3V9M8A
# 760446       5       False  07 13, 2016  B0178BYS24
# 760447       4        True  07 23, 2015  B009KY47CE
# 760448       5        True  12 14, 2015  B00X60AYDY
# 760449       5        True  02 24, 2016  B00QLD3YTO
#
#                            Prod_meta      Reviewer_Name  \
# 0                               None     Sunny  Zoeller
# 1                               None      Denise Lesley
# 2                               None               Emir
# 3               {'Color:': ' Green'}              Alyse
# 4                               None            TechGuy
# ...                              ...                ...
# 760445                          None          momahjoub
# 760446                          None              Cindy
# 760447                          None           zzrnam11
# 760448  {'Style:': ' 6-in-1 Silver'}               ACER
# 760449                          None  Toubi Chanthavong
#
#                                                    Review  \
# 0       Bought it for my husband. He's very happy with it
# 1       Great screen protector.  Doesn't even seem as ...
# 2       Saved me lots of money! it's not gorilla glass...
# 3       The material and fit is very nice, but the col...
# 4       This last me about 3 days till i have to charg...
# ...                                                   ...
# 760445                                          Very good
# 760446  My name is Cynthia Beard and I believe that th...
# 760447  This iphone case is very durable and long last...
# 760448                                              great
# 760449  So so, it did not look like the picture advert...
#
#                                                  Rev_summ  Review_timestamp  \
# 0                                    He's very happy with        1441065600
# 1                                              Five Stars        1452297600
# 2                   As long as you know how to put it on!        1366502400
# 3                                       Good case overall        1361923200
# 4                                         Awesome Battery        1387411200
# ...                                                   ...               ...
# 760445                                         Four Stars        1405123200
# 760446  ... believe that the Samsung Galaxy car mount ...        1468368000
# 760447                                        I LOVE THIS        1437609600
# 760448                                         Five Stars        1450051200
# 760449                                Front cam has hole.        1456272000
#
#        Useful Prod_img
# 0        None     None
# 1        None     None
# 2        None     None
# 3           3     None
# 4        None     None
# ...       ...      ...
# 760445   None     None
# 760446   None     None
# 760447   None     None
# 760448   None     None
# 760449   None     None
#
# [760450 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 760450 entries, 0 to 760449
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Rating            760450 non-null  int64
#  1   Rev_verify        760450 non-null  bool
#  2   Review_Date       760450 non-null  object
#  3   IC                760450 non-null  object
#  4   Prod_meta         407826 non-null  object
#  5   Reviewer_Name     760359 non-null  object
#  6   Review            759920 non-null  object
#  7   Rev_summ          760095 non-null  object
#  8   Review_timestamp  760450 non-null  int64
#  9   Useful            62200 non-null   object
#  10  Prod_img          18194 non-null   object
# dtypes: bool(1), int64(2), object(8)
# memory usage: 64.5+ MB

# %%
df.isnull().sum()
# Out:
# Rating                   0
# Rev_verify               0
# Review_Date              0
# IC                       0
# Prod_meta           352624
# Reviewer_Name           91
# Review                 530
# Rev_summ               355
# Review_timestamp         0
# Useful              698250
# Prod_img            742256
# dtype: int64

# %% [markdown]
# From the above we cab see that prod_img, useful, and prod_meta has highest number of missing vlaues, so we can simply drop that column

# %%
df.drop(['Prod_meta','Useful','Prod_img'],axis=1,inplace=True)

# %% [markdown]
# From the porblem statement we can see that review_date,reviwer_name,review_timestamp is not needed, so we can simply drop those column.

# %%
df.drop(['Review_Date','Reviewer_Name','Review_timestamp'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Rating          0
# Rev_verify      0
# IC              0
# Review        530
# Rev_summ      355
# dtype: int64

# %% [markdown]
# Now we can see that the their are missing values on review, rev_summ, so we have to replace missing values with no reviews.

# %%
df.fillna('No Reviews',inplace=True)

# %%
## Merging the reviews and reviews summary
df['Full_review'] = df[['Review', 'Rev_summ']].apply(lambda x: ' '.join(x), axis = 1)

# %%
df.isnull().sum()
# Out:
# Rating         0
# Rev_verify     0
# IC             0
# Review         0
# Rev_summ       0
# Full_review    0
# dtype: int64

# %%
df.IC.nunique()
# Out:
# 48134

# %% [markdown]
# so from the above we can see that our final DataFrame should have 48134 columns

# %%
df
# Out:
#         Rating  Rev_verify          IC  \
# 0            5        True  B009XD5TPQ
# 1            5        True  B016MF3P3K
# 2            5        True  B008DC8N5G
# 3            3        True  B0089CH3TM
# 4            4        True  B00AKZWGAC
# ...        ...         ...         ...
# 760445       4       False  B00C3V9M8A
# 760446       5       False  B0178BYS24
# 760447       4        True  B009KY47CE
# 760448       5        True  B00X60AYDY
# 760449       5        True  B00QLD3YTO
#
#                                                    Review  \
# 0       Bought it for my husband. He's very happy with it
# 1       Great screen protector.  Doesn't even seem as ...
# 2       Saved me lots of money! it's not gorilla glass...
# 3       The material and fit is very nice, but the col...
# 4       This last me about 3 days till i have to charg...
# ...                                                   ...
# 760445                                          Very good
# 760446  My name is Cynthia Beard and I believe that th...
# 760447  This iphone case is very durable and long last...
# 760448                                              great
# 760449  So so, it did not look like the picture advert...
#
#                                                  Rev_summ  \
# 0                                    He's very happy with
# 1                                              Five Stars
# 2                   As long as you know how to put it on!
# 3                                       Good case overall
# 4                                         Awesome Battery
# ...                                                   ...
# 760445                                         Four Stars
# 760446  ... believe that the Samsung Galaxy car mount ...
# 760447                                        I LOVE THIS
# 760448                                         Five Stars
# 760449                                Front cam has hole.
#
#                                               Full_review
# 0       Bought it for my husband. He's very happy with...
# 1       Great screen protector.  Doesn't even seem as ...
# 2       Saved me lots of money! it's not gorilla glass...
# 3       The material and fit is very nice, but the col...
# 4       This last me about 3 days till i have to charg...
# ...                                                   ...
# 760445                               Very good Four Stars
# 760446  My name is Cynthia Beard and I believe that th...
# 760447  This iphone case is very durable and long last...
# 760448                                   great Five Stars
# 760449  So so, it did not look like the picture advert...
#
# [760450 rows x 6 columns]

# %%
df['Average_Rating']= df.groupby(['IC'])['Rating'].transform(lambda x: (x.mean()))
df['Minimum_Rating']= df.groupby(['IC'])['Rating'].transform(lambda x: x.min())
df['Max_Rating']= df.groupby(['IC'])['Rating'].transform(lambda x: x.max())
df['Average_Rating']=df['Average_Rating'].round(decimals=1)

# %%
df
# Out:
#         Rating  Rev_verify          IC  \
# 0            5        True  B009XD5TPQ
# 1            5        True  B016MF3P3K
# 2            5        True  B008DC8N5G
# 3            3        True  B0089CH3TM
# 4            4        True  B00AKZWGAC
# ...        ...         ...         ...
# 760445       4       False  B00C3V9M8A
# 760446       5       False  B0178BYS24
# 760447       4        True  B009KY47CE
# 760448       5        True  B00X60AYDY
# 760449       5        True  B00QLD3YTO
#
#                                                    Review  \
# 0       Bought it for my husband. He's very happy with it
# 1       Great screen protector.  Doesn't even seem as ...
# 2       Saved me lots of money! it's not gorilla glass...
# 3       The material and fit is very nice, but the col...
# 4       This last me about 3 days till i have to charg...
# ...                                                   ...
# 760445                                          Very good
# 760446  My name is Cynthia Beard and I believe that th...
# 760447  This iphone case is very durable and long last...
# 760448                                              great
# 760449  So so, it did not look like the picture advert...
#
#                                                  Rev_summ  \
# 0                                    He's very happy with
# 1                                              Five Stars
# 2                   As long as you know how to put it on!
# 3                                       Good case overall
# 4                                         Awesome Battery
# ...                                                   ...
# 760445                                         Four Stars
# 760446  ... believe that the Samsung Galaxy car mount ...
# 760447                                        I LOVE THIS
# 760448                                         Five Stars
# 760449                                Front cam has hole.
#
#                                               Full_review  Average_Rating  \
# 0       Bought it for my husband. He's very happy with...             4.5
# 1       Great screen protector.  Doesn't even seem as ...             3.6
# 2       Saved me lots of money! it's not gorilla glass...             4.1
# 3       The material and fit is very nice, but the col...             4.5
# 4       This last me about 3 days till i have to charg...             4.4
# ...                                                   ...             ...
# 760445                               Very good Four Stars             3.0
# 760446  My name is Cynthia Beard and I believe that th...             4.6
# 760447  This iphone case is very durable and long last...             4.3
# 760448                                   great Five Stars             4.6
# 760449  So so, it did not look like the picture advert...             4.5
#
#         Minimum_Rating  Max_Rating
# 0                    2           5
# 1                    1           5
# 2                    1           5
# 3                    1           5
# 4                    1           5
# ...                ...         ...
# 760445               1           5
# 760446               1           5
# 760447               1           5
# 760448               1           5
# 760449               1           5
#
# [760450 rows x 9 columns]

# %%
df['Full_Review']= df.groupby(['IC'])['Full_review'].transform(lambda x: ','.join(x))

# %%
df
# Out:
#         Rating  Rev_verify          IC  \
# 0            5        True  B009XD5TPQ
# 1            5        True  B016MF3P3K
# 2            5        True  B008DC8N5G
# 3            3        True  B0089CH3TM
# 4            4        True  B00AKZWGAC
# ...        ...         ...         ...
# 760445       4       False  B00C3V9M8A
# 760446       5       False  B0178BYS24
# 760447       4        True  B009KY47CE
# 760448       5        True  B00X60AYDY
# 760449       5        True  B00QLD3YTO
#
#                                                    Review  \
# 0       Bought it for my husband. He's very happy with it
# 1       Great screen protector.  Doesn't even seem as ...
# 2       Saved me lots of money! it's not gorilla glass...
# 3       The material and fit is very nice, but the col...
# 4       This last me about 3 days till i have to charg...
# ...                                                   ...
# 760445                                          Very good
# 760446  My name is Cynthia Beard and I believe that th...
# 760447  This iphone case is very durable and long last...
# 760448                                              great
# 760449  So so, it did not look like the picture advert...
#
#                                                  Rev_summ  \
# 0                                    He's very happy with
# 1                                              Five Stars
# 2                   As long as you know how to put it on!
# 3                                       Good case overall
# 4                                         Awesome Battery
# ...                                                   ...
# 760445                                         Four Stars
# 760446  ... believe that the Samsung Galaxy car mount ...
# 760447                                        I LOVE THIS
# 760448                                         Five Stars
# 760449                                Front cam has hole.
#
#                                               Full_review  Average_Rating  \
# 0       Bought it for my husband. He's very happy with...             4.5
# 1       Great screen protector.  Doesn't even seem as ...             3.6
# 2       Saved me lots of money! it's not gorilla glass...             4.1
# 3       The material and fit is very nice, but the col...             4.5
# 4       This last me about 3 days till i have to charg...             4.4
# ...                                                   ...             ...
# 760445                               Very good Four Stars             3.0
# 760446  My name is Cynthia Beard and I believe that th...             4.6
# 760447  This iphone case is very durable and long last...             4.3
# 760448                                   great Five Stars             4.6
# 760449  So so, it did not look like the picture advert...             4.5
#
#         Minimum_Rating  Max_Rating  \
# 0                    2           5
# 1                    1           5
# 2                    1           5
# 3                    1           5
# 4                    1           5
# ...                ...         ...
# 760445               1           5
# 760446               1           5
# 760447               1           5
# 760448               1           5
# 760449               1           5
#
#                                               Full_Review
# 0       Bought it for my husband. He's very happy with...
# 1       Great screen protector.  Doesn't even seem as ...
# 2       Saved me lots of money! it's not gorilla glass...
# 3       The material and fit is very nice, but the col...
# 4       This last me about 3 days till i have to charg...
# ...                                                   ...
# 760445  poor fitting, poor quality, bad choice.  I gue...
# 760446  A great vent car mount. The magnet is strong a...
# 760447  the colors blue are like, but I like the gray ...
# 760448  Works Great! I highly Recommend this! Five Sta...
# 760449  It doesn't even cover the whole screen. I orde...
#
# [760450 rows x 10 columns]

# %%
df['Full_Review'].iloc[0]
# Out:
# 'Bought it for my husband. He\'s very happy with it He\'s very happy with,Good product.  Does exactly what the description says it will do. I recommend buying this product. Leather case holder,This is a very nice case for medium to larger smartphones.  My Droid Razor Maxx fits very nicely, the belt clip is strong spring steel, and the magnetic clasp holds very well for a magnetic design. Nice leather smartphone case,Appears to be excellent product. Fits the phone very nicely even with the hard shell back I have on my phone. I like the fact it has a belt loop and well as the clip that slides over the belt. The loop ensures the case will not come off the belt yet you have the option of just using the clip when you have to quickly remove the phone.  Time will tell concerning the durability.  The price is hard to beat. Exceptional Value,Great fit for iPhone 5 with protective case on - yes you read correctly.  Needed a belt clip to hold iPhone 5 that has a thin protective case already on. This works perfectly. Price is very good too. Works with iPhone 5 and Ballistic,The quality of this case feels nice and solid.\nMy only complaint is that it\'s a little larger to support protective cases for the phone and since I don\'t use one there\'s a lot of extra room for my phone to move around in. Nice, solid case for the phone. Large enough to support protective cases.,Good phone "holster" with belt loops and clip.  Phone fits well and appearance is as described. Good phone "holster" at a reasonable price,[July 9, 2013] After I picked up " Body Glove 9314201 DropSuit Rugged Case for Motorola Droid Razr Maxx HD - 1 Pack - Retail Packaging - Black" from seller for 9.67USD, I realized it was awesome - but since the phone won\'t fit into this "Hedocell" case when the phone is in the body glove, I have not used this case pouch.\n\nCONtributing factor: it smelled "to high heaven" when I opened the package.  Today, more than a month later, the smell much less detectable, but for a few weeks....whew! Be prepared not to use it right away...\n\nI\'ve kept it, and will try to \'stretch\' it to fit my Razr Maxx HD with the body glove...it would be nice to have this on my belt.\n\nUpdate nearly a year later.  It still sits on a shelf.  The Body Glove has saved me several times, so that takes priority over having this case. I would not recommend you buy it if you are using something like Body Glove to protect your Razr Maxx. It is too tight for a Raxr Maxx HD inside a DropSuit...without some stretching (oh, and it smells too),Better than I would expect, been using it daily for a few months with no issues.  So far it is holding up great. My Motorola Droid HD Maxx fits perfectly with a small protective cover on it. Really nice case,The case is as it was explained.  However, it does not have enough room to hold the Droid Razr Maxx HD with another cover on the phone.  I have and OtterBox on my phone now, but have ordered a smaller case.  Hopefully that cover will fit inside this holster.  I really do like the look of the holster.  One of the elastic bands on the side seems to be a tad loose, but time will tell how my new case fits inside this holster and how the holster holds up.  Thus far, I\'m a fan. Time Will Tell,This case is quite durable. Excellent price. Arrived on time and in excellent condition. Goes on your belt loop. magnetic closer Droid phone case,Happy husband Five Stars'

# %%
data=df.drop_duplicates("IC")

# %%
data
# Out:
#         Rating  Rev_verify          IC  \
# 0            5        True  B009XD5TPQ
# 1            5        True  B016MF3P3K
# 2            5        True  B008DC8N5G
# 3            3        True  B0089CH3TM
# 4            4        True  B00AKZWGAC
# ...        ...         ...         ...
# 758007       3        True  B019NW8OV2
# 758085       5        True  B00EXQ6JMA
# 758141       5       False  B01739B1XA
# 759794       3        True  B00GI8RRZE
# 760324       4        True  B0058LE8YK
#
#                                                    Review  \
# 0       Bought it for my husband. He's very happy with it
# 1       Great screen protector.  Doesn't even seem as ...
# 2       Saved me lots of money! it's not gorilla glass...
# 3       The material and fit is very nice, but the col...
# 4       This last me about 3 days till i have to charg...
# ...                                                   ...
# 758007  Cheap plastic, not a big fan.  I'm not sure i'...
# 758085  My daughter loves it !  Some past reveiws have...
# 758141  I was happy when I found this product because ...
# 759794                             Bulky and inconsistent
# 760324  I also have an Otterbox case.  The Otterbox is...
#
#                                                  Rev_summ  \
# 0                                    He's very happy with
# 1                                              Five Stars
# 2                   As long as you know how to put it on!
# 3                                       Good case overall
# 4                                         Awesome Battery
# ...                                                   ...
# 758007               Cheap case, nothing spectacular here
# 758085  My daughter loves it! Some past reveiws have c...
# 758141  Solid and holds my iPhone5 perfectly. So simpl...
# 759794                                        Three Stars
# 760324                        Excellent case for playbook
#
#                                               Full_review  Average_Rating  \
# 0       Bought it for my husband. He's very happy with...             4.5
# 1       Great screen protector.  Doesn't even seem as ...             3.6
# 2       Saved me lots of money! it's not gorilla glass...             4.1
# 3       The material and fit is very nice, but the col...             4.5
# 4       This last me about 3 days till i have to charg...             4.4
# ...                                                   ...             ...
# 758007  Cheap plastic, not a big fan.  I'm not sure i'...             3.0
# 758085  My daughter loves it !  Some past reveiws have...             5.0
# 758141  I was happy when I found this product because ...             5.0
# 759794                 Bulky and inconsistent Three Stars             3.0
# 760324  I also have an Otterbox case.  The Otterbox is...             4.0
#
#         Minimum_Rating  Max_Rating  \
# 0                    2           5
# 1                    1           5
# 2                    1           5
# 3                    1           5
# 4                    1           5
# ...                ...         ...
# 758007               3           3
# 758085               5           5
# 758141               5           5
# 759794               3           3
# 760324               4           4
#
#                                               Full_Review
# 0       Bought it for my husband. He's very happy with...
# 1       Great screen protector.  Doesn't even seem as ...
# 2       Saved me lots of money! it's not gorilla glass...
# 3       The material and fit is very nice, but the col...
# 4       This last me about 3 days till i have to charg...
# ...                                                   ...
# 758007  Cheap plastic, not a big fan.  I'm not sure i'...
# 758085  My daughter loves it !  Some past reveiws have...
# 758141  I was happy when I found this product because ...
# 759794                 Bulky and inconsistent Three Stars
# 760324  I also have an Otterbox case.  The Otterbox is...
#
# [48134 rows x 10 columns]

# %%
## WE create a small dataset to test all the features enginnering and model to run which takes a lot less time
test = df.head(20)

# %%
test
# Out:
#     Rating  Rev_verify          IC  \
# 0        5        True  B009XD5TPQ
# 1        5        True  B016MF3P3K
# 2        5        True  B008DC8N5G
# 3        3        True  B0089CH3TM
# 4        4        True  B00AKZWGAC
# 5        5        True  B00MAWPGMI
# 6        5       False  B00NB7B4GI
# 7        5        True  B00NMR6N7W
# 8        5        True  B018V60504
# 9        5       False  B00PG8TID6
# 10       1        True  B00IJJCQBA
# 11       5        True  B005NG52PO
# 12       1        True  B00I608BHU
# 13       4       False  B015Y7E3RO
# 14       2        True  B01E6312P8
# 15       5        True  B0154TCXGK
# 16       5        True  B013DP1QBK
# 17       2        True  B00C1BNBGG
# 18       5        True  B01BCUQDFW
# 19       1        True  B00BTYACJ0
#
#                                                Review  \
# 0   Bought it for my husband. He's very happy with it
# 1   Great screen protector.  Doesn't even seem as ...
# 2   Saved me lots of money! it's not gorilla glass...
# 3   The material and fit is very nice, but the col...
# 4   This last me about 3 days till i have to charg...
# 5                        Love this case, very sturdy!
# 6   Simple and good quality iPhone 6 case. Fits on...
# 7   Great screen protector for the money! Paid $1....
# 8   Nice charger. One problem, one if the two USB ...
# 9   Most battery packs for iPhones come as a total...
# 10  To tight on my phone and the bottom piece was ...
# 11  I bought this case for my wife. I put it on he...
# 12  I wish I could give this ZERO stars.  VERY UNH...
# 13  Product was received for review purposes. This...
# 14  The volume buttons work amazingly well. They a...
# 15                          I recommend this product!
# 16  It was working perfectly for the last few week...
# 17  The tools were great but the replacement scree...
# 18                                      great product
# 19  100% WRONG. this product is not what the ad me...
#
#                                              Rev_summ  \
# 0                                He's very happy with
# 1                                          Five Stars
# 2               As long as you know how to put it on!
# 3                                   Good case overall
# 4                                     Awesome Battery
# 5                                          Five Stars
# 6               Simple and good quality iPhone 6 case
# 7                                            Perfect!
# 8   Make sure your Items work before you miss the ...
# 9   This clever design combines a battery pack int...
# 10                                           One Star
# 11                          Great fit and snaps tight
# 12      I wish I could give this ZERO stars. VERY ...
# 13  It is good material and it is a nice gift for ...
# 14  What a shame. Almost perfect, but the power bu...
# 15                                         Five Stars
# 16                               What is happening!!!
# 17                                          Two Stars
# 18                                         Five Stars
# 19                                        100% WRONG.
#
#                                           Full_review  Average_Rating  \
# 0   Bought it for my husband. He's very happy with...             4.5
# 1   Great screen protector.  Doesn't even seem as ...             3.6
# 2   Saved me lots of money! it's not gorilla glass...             4.1
# 3   The material and fit is very nice, but the col...             4.5
# 4   This last me about 3 days till i have to charg...             4.4
# 5             Love this case, very sturdy! Five Stars             4.4
# 6   Simple and good quality iPhone 6 case. Fits on...             4.9
# 7   Great screen protector for the money! Paid $1....             4.8
# 8   Nice charger. One problem, one if the two USB ...             4.2
# 9   Most battery packs for iPhones come as a total...             4.4
# 10  To tight on my phone and the bottom piece was ...             4.2
# 11  I bought this case for my wife. I put it on he...             4.0
# 12  I wish I could give this ZERO stars.  VERY UNH...             4.3
# 13  Product was received for review purposes. This...             4.4
# 14  The volume buttons work amazingly well. They a...             3.9
# 15               I recommend this product! Five Stars             3.8
# 16  It was working perfectly for the last few week...             4.7
# 17  The tools were great but the replacement scree...             4.0
# 18                           great product Five Stars             4.6
# 19  100% WRONG. this product is not what the ad me...             4.1
#
#     Minimum_Rating  Max_Rating  \
# 0                2           5
# 1                1           5
# 2                1           5
# 3                1           5
# 4                1           5
# 5                1           5
# 6                4           5
# 7                4           5
# 8                1           5
# 9                1           5
# 10               1           5
# 11               1           5
# 12               1           5
# 13               4           5
# 14               1           5
# 15               1           5
# 16               1           5
# 17               2           5
# 18               1           5
# 19               1           5
#
#                                           Full_Review
# 0   Bought it for my husband. He's very happy with...
# 1   Great screen protector.  Doesn't even seem as ...
# 2   Saved me lots of money! it's not gorilla glass...
# 3   The material and fit is very nice, but the col...
# 4   This last me about 3 days till i have to charg...
# 5   Love this case, very sturdy! Five Stars,Great ...
# 6   Simple and good quality iPhone 6 case. Fits on...
# 7   Great screen protector for the money! Paid $1....
# 8   Nice charger. One problem, one if the two USB ...
# 9   Most battery packs for iPhones come as a total...
# 10  To tight on my phone and the bottom piece was ...
# 11  I bought this case for my wife. I put it on he...
# 12  I wish I could give this ZERO stars.  VERY UNH...
# 13  Product was received for review purposes. This...
# 14  The volume buttons work amazingly well. They a...
# 15  I recommend this product! Five Stars,Just rece...
# 16  It was working perfectly for the last few week...
# 17  The tools were great but the replacement scree...
# 18  great product Five Stars,Easy to put on, no pr...
# 19  100% WRONG. this product is not what the ad me...

# %%
from nltk.corpus import wordnet
import string
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.tokenize import WhitespaceTokenizer
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer() 
def clean_text(text):
    text=str(text)
    text = text.lower()
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', text)
    rem_num = re.sub('[0-9]+', '', text)
    tokenizer = RegexpTokenizer(r'\w+')
    tokens = tokenizer.tokenize(rem_num)  
    filtered_words = [w for w in tokens if len(w) > 2 if not w in stopwords.words('english')]
    stem_words=[stemmer.stem(w) for w in filtered_words]
    lemma_words=[lemmatizer.lemmatize(w) for w in stem_words]
    return " ".join(filtered_words)
test["Full_Review"] = test["Full_Review"].apply(lambda x: clean_text(x))

# %%
test
# Out:
#     Rating  Rev_verify          IC  \
# 0        5        True  B009XD5TPQ
# 1        5        True  B016MF3P3K
# 2        5        True  B008DC8N5G
# 3        3        True  B0089CH3TM
# 4        4        True  B00AKZWGAC
# 5        5        True  B00MAWPGMI
# 6        5       False  B00NB7B4GI
# 7        5        True  B00NMR6N7W
# 8        5        True  B018V60504
# 9        5       False  B00PG8TID6
# 10       1        True  B00IJJCQBA
# 11       5        True  B005NG52PO
# 12       1        True  B00I608BHU
# 13       4       False  B015Y7E3RO
# 14       2        True  B01E6312P8
# 15       5        True  B0154TCXGK
# 16       5        True  B013DP1QBK
# 17       2        True  B00C1BNBGG
# 18       5        True  B01BCUQDFW
# 19       1        True  B00BTYACJ0
#
#                                                Review  \
# 0   Bought it for my husband. He's very happy with it
# 1   Great screen protector.  Doesn't even seem as ...
# 2   Saved me lots of money! it's not gorilla glass...
# 3   The material and fit is very nice, but the col...
# 4   This last me about 3 days till i have to charg...
# 5                        Love this case, very sturdy!
# 6   Simple and good quality iPhone 6 case. Fits on...
# 7   Great screen protector for the money! Paid $1....
# 8   Nice charger. One problem, one if the two USB ...
# 9   Most battery packs for iPhones come as a total...
# 10  To tight on my phone and the bottom piece was ...
# 11  I bought this case for my wife. I put it on he...
# 12  I wish I could give this ZERO stars.  VERY UNH...
# 13  Product was received for review purposes. This...
# 14  The volume buttons work amazingly well. They a...
# 15                          I recommend this product!
# 16  It was working perfectly for the last few week...
# 17  The tools were great but the replacement scree...
# 18                                      great product
# 19  100% WRONG. this product is not what the ad me...
#
#                                              Rev_summ  \
# 0                                He's very happy with
# 1                                          Five Stars
# 2               As long as you know how to put it on!
# 3                                   Good case overall
# 4                                     Awesome Battery
# 5                                          Five Stars
# 6               Simple and good quality iPhone 6 case
# 7                                            Perfect!
# 8   Make sure your Items work before you miss the ...
# 9   This clever design combines a battery pack int...
# 10                                           One Star
# 11                          Great fit and snaps tight
# 12      I wish I could give this ZERO stars. VERY ...
# 13  It is good material and it is a nice gift for ...
# 14  What a shame. Almost perfect, but the power bu...
# 15                                         Five Stars
# 16                               What is happening!!!
# 17                                          Two Stars
# 18                                         Five Stars
# 19                                        100% WRONG.
#
#                                           Full_review  Average_Rating  \
# 0   Bought it for my husband. He's very happy with...             4.5
# 1   Great screen protector.  Doesn't even seem as ...             3.6
# 2   Saved me lots of money! it's not gorilla glass...             4.1
# 3   The material and fit is very nice, but the col...             4.5
# 4   This last me about 3 days till i have to charg...             4.4
# 5             Love this case, very sturdy! Five Stars             4.4
# 6   Simple and good quality iPhone 6 case. Fits on...             4.9
# 7   Great screen protector for the money! Paid $1....             4.8
# 8   Nice charger. One problem, one if the two USB ...             4.2
# 9   Most battery packs for iPhones come as a total...             4.4
# 10  To tight on my phone and the bottom piece was ...             4.2
# 11  I bought this case for my wife. I put it on he...             4.0
# 12  I wish I could give this ZERO stars.  VERY UNH...             4.3
# 13  Product was received for review purposes. This...             4.4
# 14  The volume buttons work amazingly well. They a...             3.9
# 15               I recommend this product! Five Stars             3.8
# 16  It was working perfectly for the last few week...             4.7
# 17  The tools were great but the replacement scree...             4.0
# 18                           great product Five Stars             4.6
# 19  100% WRONG. this product is not what the ad me...             4.1
#
#     Minimum_Rating  Max_Rating  \
# 0                2           5
# 1                1           5
# 2                1           5
# 3                1           5
# 4                1           5
# 5                1           5
# 6                4           5
# 7                4           5
# 8                1           5
# 9                1           5
# 10               1           5
# 11               1           5
# 12               1           5
# 13               4           5
# 14               1           5
# 15               1           5
# 16               1           5
# 17               2           5
# 18               1           5
# 19               1           5
#
#                                           Full_Review
# 0   bought husband happy happy good product exactl...
# 1   great screen protector even seem though five s...
# 2   saved lots money gorilla glass careful subject...
# 3   material fit nice color neon green expected wo...
# 4   last days till charge take forever charge make...
# 5   love case sturdy five stars great looking case...
# 6   simple good quality iphone case fits perfectly...
# 7   great screen protector money paid free shippin...
# 8   nice charger one problem one two usb slots mis...
# 9   battery packs iphones come totally separate de...
# 10  tight phone bottom piece missing one star ever...
# 11  bought case wife put phone worried cheap case ...
# 12  wish could give zero stars unhappy missed retu...
# 13  product received review purposes stand specifi...
# 14  volume buttons work amazingly well seated perf...
# 15  recommend product five stars received mail exc...
# 16  working perfectly last weeks last night plugge...
# 17  tools great replacement screen foggy two stars...
# 18  great product five stars easy put problems fiv...
# 19  wrong product mentions case iphone mentioned d...

# %%
def pos_tag(text):
    wordsList = nltk.word_tokenize(text) 
    tagged = nltk.pos_tag(wordsList)   
    return tagged
test['tagged']=test['Full_Review'].apply(lambda s:pos_tag(s))

# %%
test
# Out:
#     Rating  Rev_verify          IC  \
# 0        5        True  B009XD5TPQ
# 1        5        True  B016MF3P3K
# 2        5        True  B008DC8N5G
# 3        3        True  B0089CH3TM
# 4        4        True  B00AKZWGAC
# 5        5        True  B00MAWPGMI
# 6        5       False  B00NB7B4GI
# 7        5        True  B00NMR6N7W
# 8        5        True  B018V60504
# 9        5       False  B00PG8TID6
# 10       1        True  B00IJJCQBA
# 11       5        True  B005NG52PO
# 12       1        True  B00I608BHU
# 13       4       False  B015Y7E3RO
# 14       2        True  B01E6312P8
# 15       5        True  B0154TCXGK
# 16       5        True  B013DP1QBK
# 17       2        True  B00C1BNBGG
# 18       5        True  B01BCUQDFW
# 19       1        True  B00BTYACJ0
#
#                                                Review  \
# 0   Bought it for my husband. He's very happy with it
# 1   Great screen protector.  Doesn't even seem as ...
# 2   Saved me lots of money! it's not gorilla glass...
# 3   The material and fit is very nice, but the col...
# 4   This last me about 3 days till i have to charg...
# 5                        Love this case, very sturdy!
# 6   Simple and good quality iPhone 6 case. Fits on...
# 7   Great screen protector for the money! Paid $1....
# 8   Nice charger. One problem, one if the two USB ...
# 9   Most battery packs for iPhones come as a total...
# 10  To tight on my phone and the bottom piece was ...
# 11  I bought this case for my wife. I put it on he...
# 12  I wish I could give this ZERO stars.  VERY UNH...
# 13  Product was received for review purposes. This...
# 14  The volume buttons work amazingly well. They a...
# 15                          I recommend this product!
# 16  It was working perfectly for the last few week...
# 17  The tools were great but the replacement scree...
# 18                                      great product
# 19  100% WRONG. this product is not what the ad me...
#
#                                              Rev_summ  \
# 0                                He's very happy with
# 1                                          Five Stars
# 2               As long as you know how to put it on!
# 3                                   Good case overall
# 4                                     Awesome Battery
# 5                                          Five Stars
# 6               Simple and good quality iPhone 6 case
# 7                                            Perfect!
# 8   Make sure your Items work before you miss the ...
# 9   This clever design combines a battery pack int...
# 10                                           One Star
# 11                          Great fit and snaps tight
# 12      I wish I could give this ZERO stars. VERY ...
# 13  It is good material and it is a nice gift for ...
# 14  What a shame. Almost perfect, but the power bu...
# 15                                         Five Stars
# 16                               What is happening!!!
# 17                                          Two Stars
# 18                                         Five Stars
# 19                                        100% WRONG.
#
#                                           Full_review  Average_Rating  \
# 0   Bought it for my husband. He's very happy with...             4.5
# 1   Great screen protector.  Doesn't even seem as ...             3.6
# 2   Saved me lots of money! it's not gorilla glass...             4.1
# 3   The material and fit is very nice, but the col...             4.5
# 4   This last me about 3 days till i have to charg...             4.4
# 5             Love this case, very sturdy! Five Stars             4.4
# 6   Simple and good quality iPhone 6 case. Fits on...             4.9
# 7   Great screen protector for the money! Paid $1....             4.8
# 8   Nice charger. One problem, one if the two USB ...             4.2
# 9   Most battery packs for iPhones come as a total...             4.4
# 10  To tight on my phone and the bottom piece was ...             4.2
# 11  I bought this case for my wife. I put it on he...             4.0
# 12  I wish I could give this ZERO stars.  VERY UNH...             4.3
# 13  Product was received for review purposes. This...             4.4
# 14  The volume buttons work amazingly well. They a...             3.9
# 15               I recommend this product! Five Stars             3.8
# 16  It was working perfectly for the last few week...             4.7
# 17  The tools were great but the replacement scree...             4.0
# 18                           great product Five Stars             4.6
# 19  100% WRONG. this product is not what the ad me...             4.1
#
#     Minimum_Rating  Max_Rating  \
# 0                2           5
# 1                1           5
# 2                1           5
# 3                1           5
# 4                1           5
# 5                1           5
# 6                4           5
# 7                4           5
# 8                1           5
# 9                1           5
# 10               1           5
# 11               1           5
# 12               1           5
# 13               4           5
# 14               1           5
# 15               1           5
# 16               1           5
# 17               2           5
# 18               1           5
# 19               1           5
#
#                                           Full_Review  \
# 0   bought husband happy happy good product exactl...
# 1   great screen protector even seem though five s...
# 2   saved lots money gorilla glass careful subject...
# 3   material fit nice color neon green expected wo...
# 4   last days till charge take forever charge make...
# 5   love case sturdy five stars great looking case...
# 6   simple good quality iphone case fits perfectly...
# 7   great screen protector money paid free shippin...
# 8   nice charger one problem one two usb slots mis...
# 9   battery packs iphones come totally separate de...
# 10  tight phone bottom piece missing one star ever...
# 11  bought case wife put phone worried cheap case ...
# 12  wish could give zero stars unhappy missed retu...
# 13  product received review purposes stand specifi...
# 14  volume buttons work amazingly well seated perf...
# 15  recommend product five stars received mail exc...
# 16  working perfectly last weeks last night plugge...
# 17  tools great replacement screen foggy two stars...
# 18  great product five stars easy put problems fiv...
# 19  wrong product mentions case iphone mentioned d...
#
#                                                tagged
# 0   [(bought, JJ), (husband, NN), (happy, JJ), (ha...
# 1   [(great, JJ), (screen, NN), (protector, NN), (...
# 2   [(saved, VBN), (lots, NNS), (money, NN), (gori...
# 3   [(material, JJ), (fit, NN), (nice, JJ), (color...
# 4   [(last, JJ), (days, NNS), (till, VB), (charge,...
# 5   [(love, VB), (case, NN), (sturdy, JJ), (five, ...
# 6   [(simple, NN), (good, JJ), (quality, NN), (iph...
# 7   [(great, JJ), (screen, JJ), (protector, NN), (...
# 8   [(nice, JJ), (charger, NN), (one, CD), (proble...
# 9   [(battery, NN), (packs, VBZ), (iphones, NNS), ...
# 10  [(tight, JJ), (phone, NN), (bottom, NN), (piec...
# 11  [(bought, JJ), (case, NN), (wife, NN), (put, V...
# 12  [(wish, NN), (could, MD), (give, VB), (zero, C...
# 13  [(product, NN), (received, VBD), (review, JJ),...
# 14  [(volume, NN), (buttons, NNS), (work, VBP), (a...
# 15  [(recommend, VB), (product, NN), (five, CD), (...
# 16  [(working, VBG), (perfectly, RB), (last, JJ), ...
# 17  [(tools, NNS), (great, JJ), (replacement, NN),...
# 18  [(great, JJ), (product, NN), (five, CD), (star...
# 19  [(wrong, JJ), (product, NN), (mentions, NNS), ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rating          20 non-null     int64
#  1   Rev_verify      20 non-null     bool
#  2   IC              20 non-null     object
#  3   Review          20 non-null     object
#  4   Rev_summ        20 non-null     object
#  5   Full_review     20 non-null     object
#  6   Average_Rating  20 non-null     float64
#  7   Minimum_Rating  20 non-null     int64
#  8   Max_Rating      20 non-null     int64
#  9   Full_Review     20 non-null     object
#  10  tagged          20 non-null     object
# dtypes: bool(1), float64(1), int64(3), object(6)
# memory usage: 1.7+ KB

# %%
test['tagged'].iloc[0]
# Out:
# [('bought', 'JJ'),
#  ('husband', 'NN'),
#  ('happy', 'JJ'),
#  ('happy', 'JJ'),
#  ('good', 'JJ'),
#  ('product', 'NN'),
#  ('exactly', 'RB'),
#  ('description', 'NN'),
#  ('says', 'VBZ'),
#  ('recommend', 'VB'),
#  ('buying', 'VBG'),
#  ('product', 'NN'),
#  ('leather', 'NN'),
#  ('case', 'NN'),
#  ('holder', 'NN'),
#  ('nice', 'JJ'),
#  ('case', 'NN'),
#  ('medium', 'NN'),
#  ('larger', 'JJR'),
#  ('smartphones', 'NNS'),
#  ('droid', 'VBP'),
#  ('razor', 'NN'),
#  ('maxx', 'NN'),
#  ('fits', 'VBZ'),
#  ('nicely', 'RB'),
#  ('belt', 'JJ'),
#  ('clip', 'NN'),
#  ('strong', 'JJ'),
#  ('spring', 'NN'),
#  ('steel', 'NN'),
#  ('magnetic', 'JJ'),
#  ('clasp', 'NN'),
#  ('holds', 'VBZ'),
#  ('well', 'RB'),
#  ('magnetic', 'JJ'),
#  ('design', 'NN'),
#  ('nice', 'JJ'),
#  ('leather', 'RB'),
#  ('smartphone', 'NN'),
#  ('case', 'NN'),
#  ('appears', 'VBZ'),
#  ('excellent', 'JJ'),
#  ('product', 'NN'),
#  ('fits', 'VBZ'),
#  ('phone', 'NN'),
#  ('nicely', 'RB'),
#  ('even', 'RB'),
#  ('hard', 'JJ'),
#  ('shell', 'NN'),
#  ('back', 'RB'),
#  ('phone', 'NN'),
#  ('like', 'IN'),
#  ('fact', 'NN'),
#  ('belt', 'NN'),
#  ('loop', 'NN'),
#  ('well', 'RB'),
#  ('clip', 'VBZ'),
#  ('slides', 'NNS'),
#  ('belt', 'VBD'),
#  ('loop', 'JJ'),
#  ('ensures', 'NNS'),
#  ('case', 'NN'),
#  ('come', 'VBP'),
#  ('belt', 'NN'),
#  ('yet', 'RB'),
#  ('option', 'NN'),
#  ('using', 'VBG'),
#  ('clip', 'JJ'),
#  ('quickly', 'RB'),
#  ('remove', 'VB'),
#  ('phone', 'NN'),
#  ('time', 'NN'),
#  ('tell', 'VB'),
#  ('concerning', 'VBG'),
#  ('durability', 'NN'),
#  ('price', 'NN'),
#  ('hard', 'JJ'),
#  ('beat', 'NN'),
#  ('exceptional', 'JJ'),
#  ('value', 'NN'),
#  ('great', 'JJ'),
#  ('fit', 'JJ'),
#  ('iphone', 'NN'),
#  ('protective', 'JJ'),
#  ('case', 'NN'),
#  ('yes', 'RB'),
#  ('read', 'VBD'),
#  ('correctly', 'RB'),
#  ('needed', 'VBN'),
#  ('belt', 'NN'),
#  ('clip', 'NN'),
#  ('hold', 'VBP'),
#  ('iphone', 'NN'),
#  ('thin', 'JJ'),
#  ('protective', 'JJ'),
#  ('case', 'NN'),
#  ('already', 'RB'),
#  ('works', 'VBZ'),
#  ('perfectly', 'RB'),
#  ('price', 'NN'),
#  ('good', 'JJ'),
#  ('works', 'VBZ'),
#  ('iphone', 'RB'),
#  ('ballistic', 'JJ'),
#  ('quality', 'NN'),
#  ('case', 'NN'),
#  ('feels', 'JJ'),
#  ('nice', 'JJ'),
#  ('solid', 'JJ'),
#  ('complaint', 'NN'),
#  ('little', 'JJ'),
#  ('larger', 'JJR'),
#  ('support', 'NN'),
#  ('protective', 'JJ'),
#  ('cases', 'NNS'),
#  ('phone', 'NN'),
#  ('since', 'IN'),
#  ('use', 'NN'),
#  ('one', 'CD'),
#  ('lot', 'NN'),
#  ('extra', 'JJ'),
#  ('room', 'NN'),
#  ('phone', 'NN'),
#  ('move', 'NN'),
#  ('around', 'IN'),
#  ('nice', 'JJ'),
#  ('solid', 'JJ'),
#  ('case', 'NN'),
#  ('phone', 'NN'),
#  ('large', 'JJ'),
#  ('enough', 'JJ'),
#  ('support', 'NN'),
#  ('protective', 'JJ'),
#  ('cases', 'NNS'),
#  ('good', 'JJ'),
#  ('phone', 'NN'),
#  ('holster', 'NN'),
#  ('belt', 'VBD'),
#  ('loops', 'NNS'),
#  ('clip', 'VBP'),
#  ('phone', 'NN'),
#  ('fits', 'NNS'),
#  ('well', 'RB'),
#  ('appearance', 'RB'),
#  ('described', 'VBN'),
#  ('good', 'JJ'),
#  ('phone', 'NN'),
#  ('holster', 'RBR'),
#  ('reasonable', 'JJ'),
#  ('price', 'NN'),
#  ('july', 'NN'),
#  ('picked', 'VBD'),
#  ('body', 'NN'),
#  ('glove', 'VB'),
#  ('dropsuit', 'NN'),
#  ('rugged', 'VBN'),
#  ('case', 'NN'),
#  ('motorola', 'NN'),
#  ('droid', 'NN'),
#  ('razr', 'NN'),
#  ('maxx', 'NN'),
#  ('pack', 'NN'),
#  ('retail', 'JJ'),
#  ('packaging', 'NN'),
#  ('black', 'JJ'),
#  ('seller', 'NN'),
#  ('usd', 'JJ'),
#  ('realized', 'VBN'),
#  ('awesome', 'JJ'),
#  ('since', 'IN'),
#  ('phone', 'NN'),
#  ('fit', 'NN'),
#  ('hedocell', 'NN'),
#  ('case', 'NN'),
#  ('phone', 'NN'),
#  ('body', 'NN'),
#  ('glove', 'VB'),
#  ('used', 'VBN'),
#  ('case', 'NN'),
#  ('pouch', 'JJ'),
#  ('contributing', 'VBG'),
#  ('factor', 'NN'),
#  ('smelled', 'VBD'),
#  ('high', 'JJ'),
#  ('heaven', 'NN'),
#  ('opened', 'VBD'),
#  ('package', 'NN'),
#  ('today', 'NN'),
#  ('month', 'NN'),
#  ('later', 'RB'),
#  ('smell', 'RB'),
#  ('much', 'RB'),
#  ('less', 'RBR'),
#  ('detectable', 'JJ'),
#  ('weeks', 'NNS'),
#  ('whew', 'RB'),
#  ('prepared', 'JJ'),
#  ('use', 'NN'),
#  ('right', 'RB'),
#  ('away', 'RB'),
#  ('kept', 'JJ'),
#  ('try', 'NN'),
#  ('stretch', 'NN'),
#  ('fit', 'NN'),
#  ('razr', 'NN'),
#  ('maxx', 'NN'),
#  ('body', 'NN'),
#  ('glove', 'VB'),
#  ('would', 'MD'),
#  ('nice', 'VB'),
#  ('belt', 'NN'),
#  ('update', 'NN'),
#  ('nearly', 'RB'),
#  ('year', 'NN'),
#  ('later', 'RB'),
#  ('still', 'RB'),
#  ('sits', 'VBZ'),
#  ('shelf', 'NN'),
#  ('body', 'NN'),
#  ('glove', 'VB'),
#  ('saved', 'VBD'),
#  ('several', 'JJ'),
#  ('times', 'NNS'),
#  ('takes', 'VBZ'),
#  ('priority', 'NN'),
#  ('case', 'NN'),
#  ('would', 'MD'),
#  ('recommend', 'VB'),
#  ('buy', 'VB'),
#  ('using', 'VBG'),
#  ('something', 'NN'),
#  ('like', 'IN'),
#  ('body', 'NN'),
#  ('glove', 'VBP'),
#  ('protect', 'NN'),
#  ('razr', 'NN'),
#  ('maxx', 'NN'),
#  ('tight', 'VBD'),
#  ('raxr', 'NN'),
#  ('maxx', 'NN'),
#  ('inside', 'IN'),
#  ('dropsuit', 'NN'),
#  ('without', 'IN'),
#  ('stretching', 'VBG'),
#  ('smells', 'NNS'),
#  ('better', 'RBR'),
#  ('would', 'MD'),
#  ('expect', 'VB'),
#  ('using', 'VBG'),
#  ('daily', 'JJ'),
#  ('months', 'NNS'),
#  ('issues', 'NNS'),
#  ('far', 'RB'),
#  ('holding', 'VBG'),
#  ('great', 'JJ'),
#  ('motorola', 'NN'),
#  ('droid', 'NN'),
#  ('maxx', 'NN'),
#  ('fits', 'VBZ'),
#  ('perfectly', 'RB'),
#  ('small', 'JJ'),
#  ('protective', 'JJ'),
#  ('cover', 'NN'),
#  ('really', 'RB'),
#  ('nice', 'JJ'),
#  ('case', 'NN'),
#  ('case', 'NN'),
#  ('explained', 'VBD'),
#  ('however', 'RB'),
#  ('enough', 'JJ'),
#  ('room', 'NN'),
#  ('hold', 'VBP'),
#  ('droid', 'JJ'),
#  ('razr', 'NN'),
#  ('maxx', 'NN'),
#  ('another', 'DT'),
#  ('cover', 'NN'),
#  ('phone', 'NN'),
#  ('otterbox', 'JJ'),
#  ('phone', 'NN'),
#  ('ordered', 'VBD'),
#  ('smaller', 'JJR'),
#  ('case', 'NN'),
#  ('hopefully', 'RB'),
#  ('cover', 'RB'),
#  ('fit', 'JJ'),
#  ('inside', 'IN'),
#  ('holster', 'NN'),
#  ('really', 'RB'),
#  ('like', 'JJ'),
#  ('look', 'NN'),
#  ('holster', 'NN'),
#  ('one', 'CD'),
#  ('elastic', 'JJ'),
#  ('bands', 'NNS'),
#  ('side', 'RB'),
#  ('seems', 'VBZ'),
#  ('tad', 'JJ'),
#  ('loose', 'JJ'),
#  ('time', 'NN'),
#  ('tell', 'VB'),
#  ('new', 'JJ'),
#  ('case', 'NN'),
#  ('fits', 'VBZ'),
#  ('inside', 'RB'),
#  ('holster', 'JJ'),
#  ('holster', 'NN'),
#  ('holds', 'VBZ'),
#  ('thus', 'RB'),
#  ('far', 'RB'),
#  ('fan', 'JJ'),
#  ('time', 'NN'),
#  ('tell', 'VB'),
#  ('case', 'NN'),
#  ('quite', 'RB'),
#  ('durable', 'JJ'),
#  ('excellent', 'JJ'),
#  ('price', 'NN'),
#  ('arrived', 'VBD'),
#  ('time', 'NN'),
#  ('excellent', 'JJ'),
#  ('condition', 'NN'),
#  ('goes', 'VBZ'),
#  ('belt', 'RB'),
#  ('loop', 'JJ'),
#  ('magnetic', 'JJ'),
#  ('closer', 'JJR'),
#  ('droid', 'NN'),
#  ('phone', 'NN'),
#  ('case', 'NN'),
#  ('happy', 'JJ'),
#  ('husband', 'NN'),
#  ('five', 'CD'),
#  ('stars', 'NNS')]

# %%
def Aspect(text):
    prevWord=''
    prevTags=''
    currWord=''
    aspectList=[]
    outputDict={}
    #it = iter(text)
    #text_dict=dict(zip(it,it))
    #print(text_dict)
    for value in text:
        word,tag=value
        #for word,tag in value:
        if(tag=='NN' or tag=='NNP'):
            if(prevTags=='NN' or prevTags=='NNP'):
                currWord= prevWord + ' ' + word
            else:
                aspectList.append(prevWord.upper())
                currWord= word
        prevWord=currWord
        prevTags=tag
    return aspectList
    #for aspect in aspectList:
        #if(aspectList.count(aspect)>1):
                #if(outputDict.keys()!=aspect):
                        #outputDict[aspect]=aspectList.count(aspect)
   # outputAspect=sorted(outputDict.items(), key=lambda x: x[1],reverse = True)
   # return outputAspect
test['Aspect'] = test['tagged'].apply(lambda s:Aspect(s))

# %%
test['Aspect'].iloc[0]
# Out:
# ['',
#  'HUSBAND',
#  'PRODUCT',
#  'DESCRIPTION',
#  'PRODUCT LEATHER CASE HOLDER',
#  'CASE MEDIUM',
#  'RAZOR MAXX',
#  'CLIP',
#  'SPRING STEEL',
#  'CLASP',
#  'DESIGN',
#  'SMARTPHONE CASE',
#  'PRODUCT',
#  'PHONE',
#  'SHELL',
#  'PHONE',
#  'FACT BELT LOOP',
#  'CASE',
#  'BELT',
#  'OPTION',
#  'PHONE TIME',
#  'DURABILITY PRICE',
#  'BEAT',
#  'VALUE',
#  'IPHONE',
#  'CASE',
#  'BELT CLIP',
#  'IPHONE',
#  'CASE',
#  'PRICE',
#  'QUALITY CASE',
#  'COMPLAINT',
#  'SUPPORT',
#  'PHONE',
#  'USE',
#  'LOT',
#  'ROOM PHONE MOVE',
#  'CASE PHONE',
#  'SUPPORT',
#  'PHONE HOLSTER',
#  'PHONE',
#  'PHONE',
#  'PRICE JULY',
#  'BODY',
#  'DROPSUIT',
#  'CASE MOTOROLA DROID RAZR MAXX PACK',
#  'PACKAGING',
#  'SELLER',
#  'PHONE FIT HEDOCELL CASE PHONE BODY',
#  'CASE',
#  'FACTOR',
#  'HEAVEN',
#  'PACKAGE TODAY MONTH',
#  'USE',
#  'TRY STRETCH FIT RAZR MAXX BODY',
#  'BELT UPDATE',
#  'YEAR',
#  'SHELF BODY',
#  'PRIORITY CASE',
#  'SOMETHING',
#  'BODY',
#  'PROTECT RAZR MAXX',
#  'RAXR MAXX',
#  'DROPSUIT',
#  'MOTOROLA DROID MAXX',
#  'COVER',
#  'CASE CASE',
#  'ROOM',
#  'RAZR MAXX',
#  'COVER PHONE',
#  'PHONE',
#  'CASE',
#  'HOLSTER',
#  'LOOK HOLSTER',
#  'TIME',
#  'CASE',
#  'HOLSTER',
#  'TIME',
#  'CASE',
#  'PRICE',
#  'TIME',
#  'CONDITION',
#  'DROID PHONE CASE']

# %%
def custom_liu_hu_lexicon(sentence):
    '''Takes in a sentence and returns the sentiment of the sentence by counting the no of positive and negitive 
    and negitive words and by reversing the sentiment if the words NO or NOT are present
    '''
    from nltk.corpus import opinion_lexicon
    from nltk.tokenize import treebank

    tokenizer = treebank.TreebankWordTokenizer()
    pos_words = 0
    neg_words = 0
    tokenized_sent = [word.lower() for word in tokenizer.tokenize(sentence)]

    x = list(range(len(tokenized_sent))) 
    y = []
    isNegation = False
    negationWords = ['no','not','never','none','bad','hardly','rarely','scarcely','']

    for word in tokenized_sent:
        if word in opinion_lexicon.positive():
            pos_words += 1
            y.append(1) # positive
        elif word in opinion_lexicon.negative():
            neg_words += 1
            y.append(-1) # negative
        else:
            y.append(0) # neutral
            
        if word in negationWords:
            isNegation = True

    if pos_words > neg_words and isNegation==True:
        return 'neg'
    elif pos_words > neg_words:
        return 'pos'
    elif pos_words < neg_words and isNegation==True:
        return 'pos'
    elif pos_words < neg_words:
        return 'neg'
    elif pos_words == neg_words:
        return 'neutral'
#def sentiment(text):
neutral_review=[]
positive_review=[]
negative_review=[]
items=test['Aspect']
for sentence in test.Full_Review:
    for i in items:
        if i[0] in sentence:
            #print(i +"--" + sentence)
            x=custom_liu_hu_lexicon(sentence)
            if(x=="pos"):
                positive_review.append(sentence)
            elif(x=="neg"):
                negative_review.append(sentence)
            else:
                neutral_review.append(sentence)
            break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-f02c90895b54> in <module>
#      48         if i[0] in sentence:
#      49             #print(i +"--" + sentence)
# ---> 50             x=custom_liu_hu_lexicon(sentence)
#      51             if(x=="pos"):
#      52                 positive_review.append(sentence)
#
# <ipython-input-62-f02c90895b54> in custom_liu_hu_lexicon(sentence)
#      17
#      18     for word in tokenized_sent:
# ---> 19         if word in opinion_lexicon.positive():
#      20             pos_words += 1
#      21             y.append(1) # positive
#
# ~\anaconda3\lib\site-packages\nltk\collections.py in __contains__(self, value)
#     201     def __contains__(self, value):
#     202         """Return true if this list contains ``value``."""
# --> 203         return bool(self.count(value))
#     204
#     205     def __add__(self, other):
#
# ~\anaconda3\lib\site-packages\nltk\collections.py in count(self, value)
#     186     def count(self, value):
#     187         """Return the number of times this list contains ``value``."""
# --> 188         return sum(1 for elt in self if elt == value)
#     189
#     190     def index(self, value, start=None, stop=None):
#
# ~\anaconda3\lib\site-packages\nltk\collections.py in <genexpr>(.0)
#     186     def count(self, value):
#     187         """Return the number of times this list contains ``value``."""
# --> 188         return sum(1 for elt in self if elt == value)
#     189
#     190     def index(self, value, start=None, stop=None):
#
# ~\anaconda3\lib\site-packages\nltk\corpus\reader\util.py in iterate_from(self, start_tok)
#     304             self._current_toknum = toknum
#     305             self._current_blocknum = block_index
# --> 306             tokens = self.read_block(self._stream)
#     307             assert isinstance(tokens, (tuple, list, AbstractLazySequence)), (
#     308                 'block reader %s() should return list or tuple.'
#
# ~\anaconda3\lib\site-packages\nltk\corpus\reader\opinion_lexicon.py in _read_word_block(self, stream)
#     117         words = []
#     118         for i in range(20):  # Read 20 lines at a time.
# --> 119             line = stream.readline()
#     120             if not line:
#     121                 continue
#
# ~\anaconda3\lib\site-packages\nltk\data.py in readline(self, size)
#    1217
#    1218         while True:
# -> 1219             startpos = self.stream.tell() - len(self.bytebuffer)
#    1220             new_chars = self._read(readsize)
#    1221
#
# KeyboardInterrupt:

# %%
nltk.download('opinion_lexicon')
