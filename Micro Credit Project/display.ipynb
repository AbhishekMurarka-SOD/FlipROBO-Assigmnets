# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df=pd.read_csv("Data file.csv")

# %%
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  rental30  rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  fr_da_rech30  cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  medianamnt_loans90  payback30  payback90 pcircle       pdate
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0          label            aon   daily_decr30   daily_decr90       rental30       rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30   fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  medianmarechprebal30  cnt_ma_rech90   fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30   fr_da_rech30  cnt_da_rech90   fr_da_rech90    cnt_loans30   amnt_loans30  maxamnt_loans30  medianamnt_loans30    cnt_loans90   amnt_loans90  maxamnt_loans90  medianamnt_loans90      payback30      payback90
# ...

# %%
data=df[['daily_decr30', 'daily_decr90', 'rental30', 'rental90', 'last_rech_amt_ma', 'cnt_ma_rech30',
         'fr_ma_rech30', 'cnt_ma_rech90', 'cnt_loans30', 'amnt_loans30', 'cnt_loans90', 'amnt_loans90',
         'payback30', 'payback90']]

# %%
data.describe()
# Out:
#         daily_decr30   daily_decr90       rental30       rental90  last_rech_amt_ma  cnt_ma_rech30   fr_ma_rech30  cnt_ma_rech90    cnt_loans30   amnt_loans30    cnt_loans90   amnt_loans90      payback30      payback90
# count  209593.000000  209593.000000  209593.000000  209593.000000     209593.000000  209593.000000  209593.000000   209593.00000  209593.000000  209593.000000  209593.000000  209593.000000  209593.000000  209593.000000
# mean     5381.402289    6082.515068    2692.581910    3483.406534       2064.452797       3.978057    3737.355121        6.31543       2.758981      17.952021      18.520919      23.645398       3.398826       4.321485
# std      9220.623400   10918.812767    4308.586781    5770.461279       2370.786034       4.256090   53643.625172        7.19347       2.554502      17.379741     224.797423      26.469861       8.813729      10.308108
# ...
